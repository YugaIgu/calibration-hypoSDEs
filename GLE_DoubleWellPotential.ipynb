# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
import time
import scipy.stats
from jax.scipy.stats import norm
import scipy.optimize
import simsde
import symnum
import symnum.numpy as snp
import jax.numpy as jnp
from jax.scipy.linalg import cho_solve
from jax import jit, vmap, grad, value_and_grad
from jax.lax import scan
from jax.example_libraries.optimizers import adam
import matplotlib.pyplot as plt
from jax.config import config
config.update('jax_enable_x64', True)
config.update('jax_platform_name', 'cpu')

# %%
class hypo_gle_double_well:
    def __init__(self, param, initial_value, step_size_data, step_size_sim, num_data, num_simulation):
        self.param = param # θ = (D, λ, α, σ)   
        self.initial_value = initial_value  
        self.step_size_data = step_size_data
        self.step_size_sim = step_size_sim
        self.num_data = num_data
        self.num_simulation = num_simulation

    def calc_A_q(self, q, θ): # θ = (D, λ, α, σ)    
        dt = self.step_size_data
        D, λ, α ,σ = θ
        hess_U = D - jnp.sin(0.25 + 2*q)*4
        return jnp.array(
            [dt - (hess_U + (λ**2))* (dt**3) /6, λ * (dt**2) /2 - λ * α * (dt**3) / 6]
            )

    def calc_A_h(self, q, θ): 
        dt = self.step_size_data
        D, λ, α ,σ = θ
        hess_U = D - jnp.sin(0.25 + 2*q)*4
        return jnp.array(
            [ 
            [1 - (hess_U + (λ**2)) * (dt**2)/2, λ * dt - λ*α*(dt**2)/2], 
            [-λ*dt, 1 - α*dt]
            ])
    
    def calc_mu_q(self, q, θ):
        dt = self.step_size_data
        D = θ[0]
        grad_U = D*q + jnp.cos(0.25 + 2*q)*2
        return q - grad_U*(dt**2)/2 

    def matrix_A(self, q, θ):
        D, λ, α ,σ = θ
        dt = self.step_size_data
        hess_U = D - jnp.sin(0.25 + 2*q)*4
        return jnp.array([
            [dt - (hess_U + (λ**2)) * (dt**3) /6, λ * (dt**2) /2 - λ * α * (dt**3) / 6],
            [1 - (hess_U + (λ**2)) * (dt**2) /2, λ * dt - λ * α * (dt**2) /2], 
            [-λ*dt, 1 - α*dt]
            ]) 
    
    # This is used to generate the true trajectories of sample paths  
    def mean_one_step_sim(self, x, θ): 
        q = x[0]
        h = x[1:]
        dt = self.step_size_sim
        D, λ, α ,σ = θ
        grad_U = D*q + jnp.cos(0.25 + 2*q)*2
        hess_U = D - jnp.sin(0.25 + 2*q)*4
        matrix_A = jnp.array([
            [dt - (hess_U + (λ**2)) * (dt**3) /6, λ * (dt**2) /2 - λ * α * (dt**3) / 6],
            [1 - (hess_U + (λ**2)) * (dt**2) /2, λ * dt - λ * α * (dt**2) /2], 
            [-λ*dt, 1 - α*dt]
            ]) 
        return jnp.array([q - grad_U*(dt**2)/2, - grad_U*dt, 0]) + jnp.dot(matrix_A, h) 
    
    def mean_one_step(self, current_q, current_h, θ):
        dt = self.step_size_data
        D, λ, α ,σ = θ
        grad_U = D*current_q + jnp.cos(0.25 + 2*current_q)*2
        hess_U = D - jnp.sin(0.25 + 2*current_q)*4
        matrix_A = jnp.array([
            [dt - (hess_U + (λ**2)) * (dt**3) /6, λ * (dt**2) /2 - λ * α * (dt**3) / 6],
            [1 - (hess_U + (λ**2)) * (dt**2) /2, λ * dt - λ * α * (dt**2) /2], 
            [-λ*dt, 1 - α*dt]
            ]) 
        return jnp.array([current_q - grad_U*(dt**2)/2,  - grad_U*dt, 0]) + jnp.dot(matrix_A, current_h) 
    
    def covariance_one_step_sim(self, θ):
        dt = self.step_size_sim
        D, λ, α ,σ = θ
        return (σ**2)*jnp.array([
            [(λ**2)*(dt**5)/20, (λ**2)*(dt**4)/8, λ*(dt**3)/6], 
            [(λ**2)*(dt**4)/8, (λ**2)*(dt**3)/3, λ*(dt**2)/2], 
            [λ*(dt**3)/6, λ*(dt**2)/2, dt]
            ])
    
    def covariance_one_step(self, θ):
        dt = self.step_size_data
        D, λ, α ,σ = θ
        return (σ**2)*jnp.array([
            [(λ**2)*(dt**5)/20, (λ**2)*(dt**4)/8, λ*(dt**3)/6], 
            [(λ**2)*(dt**4)/8, (λ**2)*(dt**3)/3, λ*(dt**2)/2], 
            [λ*(dt**3)/6, λ*(dt**2)/2, dt]
            ])

    def generate_sample_paths(self, θ, seed=20230606):
        np.random.seed(seed)
        seq_rvs = np.random.multivariate_normal(np.zeros(3), self.covariance_one_step_sim(θ), size=self.num_simulation)
        x_0 = self.initial_value
        
        @jit
        def step_func(x, noise):
            x_next = self.mean_one_step_sim(x, θ) + noise
            return x_next, x_next 
        
        _, x_seq = scan(step_func, x_0, seq_rvs) 

        return jnp.concatenate((x_0[None], x_seq))
    
    def prediction_covariance(self, q, forward_filter_covariance, θ):
        Σ =self.covariance_one_step(θ)
        A = self.matrix_A(q, θ)
        pred_cov =  Σ + A @ forward_filter_covariance @ A.T 
        pred_cov_qq = pred_cov[0,0]
        pred_cov_hq = pred_cov[1:,0]
        pred_cov_hh = pred_cov[1:, 1:]
        return pred_cov_qq, pred_cov_hq, pred_cov_hh
    
    
    def prediction_mean(self, q, forward_filter_mean, θ):
        pred_mean = self.mean_one_step(q, forward_filter_mean, θ) 
        pred_mean_q = pred_mean[0]
        pred_mean_h = pred_mean[1:]
        return pred_mean_q, pred_mean_h
    

    def forward_filter_mean_cov_one_step(self, current_q, next_q, forward_filter_mean, forward_filter_covariance, θ):
        μ_q, μ_h = self.prediction_mean(current_q, forward_filter_mean, θ)
        Λ_qq, Λ_hq, Λ_hh = self.prediction_covariance(current_q, forward_filter_covariance, θ) 
        next_filter_mean = μ_h + ((next_q - μ_q)/Λ_qq)*Λ_hq
        mat = jnp.array([[Λ_hq[0]**2, Λ_hq[0]*Λ_hq[1]], [Λ_hq[0]*Λ_hq[1], Λ_hq[1]**2]])
        next_filter_cov = Λ_hh - mat / Λ_qq
        return next_filter_mean, next_filter_cov
    
    
    def forward_filter_mean_cov_paths_scan(self, q_paths, initial_mean, initial_cov, θ):
        @jit
        def step_func(filter_mean_cov, q_paths_current_next):
            filter_mean, filter_cov = filter_mean_cov
            q_current, q_next = q_paths_current_next
            filter_next = self.forward_filter_mean_cov_one_step(q_current, q_next, filter_mean, filter_cov, θ)
            return filter_next, filter_next 
        
        _, filter_mean_cov = scan(step_func, (initial_mean, initial_cov), (q_paths[:-1], q_paths[1:]))
        filter_mean, filter_cov = filter_mean_cov

        return jnp.concatenate((initial_mean[None], filter_mean)), jnp.concatenate((initial_cov[None], filter_cov)) 
    
    def get_contrast_function_scan(self, θ, q_paths, initial_mean, initial_cov):
        filter_mean_paths, filter_cov_paths = self.forward_filter_mean_cov_paths_scan(q_paths, initial_mean, initial_cov, θ)
        initial_log_likelihood = norm.logpdf(q_paths[0], loc = q_paths[0], scale = 1.0)
        Σ = self.covariance_one_step(θ)

        @jit
        def step_func(loglikelihood, qset_and_filtermeancov):
            q_current, q_next, filter_mean, filter_cov = qset_and_filtermeancov
            A_q = self.calc_A_q(q_current, θ)
            q_mean = self.calc_mu_q(q_current, θ) + jnp.dot(A_q, filter_mean)
            vec = A_q @ filter_cov
            scalar = jnp.dot(vec, A_q)
            q_scale = jnp.sqrt(scalar + Σ[0,0])
            loglikelihood_next = loglikelihood + norm.logpdf(q_next, q_mean, q_scale)
            return loglikelihood_next, loglikelihood_next
        
        _, log_likelihood_seq = scan(step_func, initial_log_likelihood, (q_paths[:-1], q_paths[1:], filter_mean_paths[:-1,:], filter_cov_paths[:-1,:,:]))

        return -2*log_likelihood_seq[-1]

# %%
def drift_position(x, θ):
    return snp.array([x[1]])

def drift_momentum(x, θ):
    D, λ, *_ = θ
    grad_potential = D*x[2] + snp.cos(0.25 + 2*x[2])*2
    return snp.array([- grad_potential + λ*x[0]])

def diff_coeff_rough(x, θ):
    *_, σ = θ
    return snp.array([[σ]])

def drift_rough(x, θ):
    D, λ, α, *_ = θ
    return snp.array([- λ*x[1] - α*x[0]])

def drift_smooth(x, θ):
    return snp.concatenate((drift_momentum(x, θ), drift_position(x, θ)))

def drift_func(x, θ):
    return snp.concatenate((drift_rough(x, θ), drift_smooth(x, θ)))

def diff_coeff(x, θ):
    *_, σ = θ
    return snp.array([[σ], [0], [0]])

dim_x = 3
dim_s1 = 1
dim_s2 = 1
dim_r = 1
dim_θ = 4 
dim_w = 1

# %%
symolic_log_transition_density_generators = {
    'local_gaussian (p = 2)': simsde.densities.local_gaussian_log_transition_density_ii,
}
jax_log_transition_densities = {
    key: symnum.numpify(dim_x, dim_x, dim_θ, None, numpy_module=jnp)(
        symbolic_transition_density_generator(
            drift_position, drift_momentum, drift_rough, diff_coeff_rough
        )
    )
    for key, symbolic_transition_density_generator in 
    symolic_log_transition_density_generators.items()
}

# %%
def get_log_likelihood_functions(log_transition_density):
    
    @jit
    def log_likelihood_θ(θ, x_seq, t_seq):
        log_transition_density_terms = vmap(log_transition_density, (0, 0, None, 0))(
            x_seq[1:], x_seq[:-1], θ, t_seq[1:] - t_seq[:-1]
        )
        return log_transition_density_terms.sum()
            
    return {'θ': log_likelihood_θ}

# %%
dim_n, step_func = {
    "euler_maruyama": (
        dim_r,
        simsde.integrators.euler_maruyama_step(drift_func, diff_coeff),
    ),
    "local_gaussian_ii": (
        3*dim_r,
        simsde.integrators.hypoelliptic_ii_local_gaussian_step(
        drift_func, drift_rough, drift_position, drift_momentum, diff_coeff_rough)
    )
}["local_gaussian_ii"]

jax_step_func = symnum.numpify(dim_x, dim_θ, dim_n, (), numpy_module=jnp)(step_func)

@jit
def simulate_diffusion(x_0, θ, t_seq, n_seq):
    
    def step_func(x, n_dt):
        n, dt = n_dt
        x_next = jax_step_func(x, θ, n, dt)
        return x_next, x_next
    
    _, x_seq = scan(step_func, x_0, (n_seq, t_seq[1:] - t_seq[:-1]))
    
    return jnp.concatenate((x_0[None], x_seq))

# %% [markdown]
# Computation of maximum likelihood estimates

# %%
rng = np.random.default_rng(20230204)
dt_simulation = 1e-4 # step size for synthetic data 
dt_obs = 1e-3  # step size for the observation 
T = 200 # Time length of data step
n_simulation = int(T / dt_simulation)
sub_interval = int(dt_obs/dt_simulation)
n_data = int(T / dt_obs) # number of data 
θ_true = jnp.array([1.0, 2.0, 4.0, 4.0]) # param θ = (D, λ, α, σ) 
x_0 = jnp.array([0.0, 0.0, 0.0]) # initial value  
t_seq_sim = np.arange(int(T / dt_simulation) + 1) * dt_simulation
model = hypo_gle_double_well(θ_true, x_0, dt_obs, dt_simulation, n_data, n_simulation)
initial_mean = jnp.array([0.0, 0.0])
initial_cov = jnp.array([[1.0, 0.0], [0.0, 1.0]])

# %%
def compute_contrast_estimator(q_obs, θ_0, initial_mean, initial_cov, optimizer=adam, n_steps=2000, step_size= 0.2):
    optimizer_init, optimizer_update, optimizer_get_params = optimizer(step_size) 

    @jit
    def optimizer_step(state, q_obs, initial_mean, initial_cov, step_index):
        value, grad = value_and_grad(model.get_contrast_function_scan)(
            optimizer_get_params(state), q_obs, initial_mean, initial_cov
        )
        state = optimizer_update(step_index, grad, state)
        return value, state
    
    state = optimizer_init(θ_0)

    for s in range(n_steps):
        _, state = optimizer_step(state, q_obs, initial_mean, initial_cov, s)
        # print(optimizer_get_params(state))
        
    return optimizer_get_params(state)


log_transition_density = jax_log_transition_densities["local_gaussian (p = 2)"]
log_likelihood = get_log_likelihood_functions(log_transition_density)

def compute_complete_maximum_likelihood_estimates(
    t_seq, x_seqs, θ_0, optimizer=adam, n_steps=2000, step_size=0.2
):
    optimizer_init, optimizer_update, optimizer_get_params = optimizer(step_size)
    
    @jit 
    def optimizer_step(step_index, state, x_seq, t_seq):
        value, grad = value_and_grad(log_likelihood["θ"])(
            optimizer_get_params(state), x_seq, t_seq
        )
        state = optimizer_update(step_index, -grad, state)
        return value, state

    state = optimizer_init(θ_0)

    for s in range(n_steps):
        _, state = optimizer_step(s, state, x_seqs, t_seq)
        # print(optimizer_get_params(state))
        
    return optimizer_get_params(state)

# %%
num_sampling = 50
D_sample_complete = np.empty((num_sampling))
λ_sample_complete = np.empty((num_sampling))
α_sample_complete = np.empty((num_sampling))
σ_sample_complete = np.empty((num_sampling))
D_sample_partial = np.empty((num_sampling))
λ_sample_partial = np.empty((num_sampling))
α_sample_partial = np.empty((num_sampling))
σ_sample_partial = np.empty((num_sampling))
seed = 20230624

for k in range(num_sampling):
    rng = np.random.default_rng(seed)
    n_seqs = rng.standard_normal((t_seq_sim.shape[0] - 1, dim_n))
    print("Compute the observations -- Start")
    x_seqs_sim = simulate_diffusion(x_0, θ_true, t_seq_sim, n_seqs)
    x_seq_obs = x_seqs_sim[::sub_interval]
    print("Compute the observations -- End")
    q_paths_obs = x_seq_obs[:, 2]
    t_seq_obs = t_seq_sim[::sub_interval]
    θ_0 = jnp.array([3.0, 3.0, 3.0, 3.0])
    print("Optimisation Complete Observation Adam -- Start")
    complete_adam = compute_complete_maximum_likelihood_estimates(t_seq_obs, x_seq_obs, θ_0)
    print("Optimisation Complete Observation Adam -- End")
    print(complete_adam)
    print(value_and_grad(log_likelihood["θ"])(complete_adam, x_seq_obs, t_seq_obs))
    print("Optimisation Partial Observation Adam -- Start")
    θ_0 = jnp.array([3.0, 3.0, 3.0, 3.0])
    partial_adam = compute_contrast_estimator(q_paths_obs, θ_0, initial_mean, initial_cov)
    print("Optimisation Partial Observation Adam -- End")
    print(partial_adam)
    print(value_and_grad(model.get_contrast_function_scan)(partial_adam, q_paths_obs, initial_mean, initial_cov))
    print(k)
    D_sample_complete[k] = complete_adam[0]
    λ_sample_complete[k] = complete_adam[1]
    α_sample_complete[k] = complete_adam[2]
    σ_sample_complete[k] = complete_adam[3]
    D_sample_partial[k] = partial_adam[0]
    λ_sample_partial[k] = partial_adam[1]
    α_sample_partial[k] = partial_adam[2]
    σ_sample_partial[k] = partial_adam[3]
    seed += 1
# Out:
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [0.99995239 1.99981092 4.30193127 4.00035451]
# (Array(5163086.71102535, dtype=float64), Array([ 5.85175185e-04,  4.27526097e-02, -5.90789639e-11, -5.25647681e+01],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [0.98631957 2.02087181 4.30156715 3.95526904]
# (Array(-5668949.52382643, dtype=float64), Array([-6.96084740e-05,  2.32193113e-01, -5.51081177e-06, -1.99654107e-01],      dtype=float64))
# 0
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [1.00010788 2.00002296 3.70599256 4.01096938]
# (Array(5162570.18518175, dtype=float64), Array([-4.36903344e-02,  3.84898988e-01, -1.61746727e-10, -6.08832887e+02],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [1.08908294 1.87180396 3.72206063 4.27350421]
# (Array(-5668629.52030854, dtype=float64), Array([-3.01612859e-04,  5.22541195e-01,  9.96424171e-06, -6.51379773e-01],      dtype=float64))
# 1
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [1.0000017  2.00012787 4.15531907 4.00415048]
# (Array(5163698.10957222, dtype=float64), Array([ 4.31659406e-02,  5.45009814e-01, -4.83680873e-10, -6.73802571e+02],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [0.92695106 1.84100058 4.17004384 4.34568237]
# (Array(-5668636.83484708, dtype=float64), Array([ 2.00558092e-02,  6.63356479e+01, -9.84016706e-03,  2.57622152e+01],      dtype=float64))
# 2
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [0.9999101  1.99972184 4.30755268 4.00470584]
# (Array(5162607.97887646, dtype=float64), Array([-1.22788181e-02,  9.68773296e-02, -8.58703553e-10, -1.30284294e+02],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [1.09919495 1.81891725 4.32952704 4.3993553 ]
# (Array(-5668500.58445922, dtype=float64), Array([-2.31995648e-04,  8.55607644e-01, -2.48772897e-05, -7.35004819e-01],      dtype=float64))
# 3
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [0.99999589 1.99995796 4.04170155 4.00365998]
# (Array(5162654.65372078, dtype=float64), Array([ 7.85232392e-03,  7.87419232e-02,  3.74764109e-11, -9.89403594e+01],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [0.9067988  2.07283424 4.05919828 3.85948254]
# (Array(-5668593.24009014, dtype=float64), Array([-2.68910937e-04,  1.74585907e-01,  5.05014044e-05, -6.35578508e-01],      dtype=float64))
# 4
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [1.00014995 2.00001061 4.20343642 3.99836186]
# (Array(5163295.99861358, dtype=float64), Array([ 1.14821534e-03,  2.35440778e-02, -9.55044377e-11, -2.77222179e+01],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [0.95700101 2.01229412 4.20171437 3.96144411]
# (Array(-5669428.93382361, dtype=float64), Array([-1.53391331e-01, -5.92084590e+02,  1.04409696e-01, -3.00788262e+02],      dtype=float64))
# 5
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [1.00006398 1.99990444 3.90585634 3.99677947]
# (Array(5163657.30420266, dtype=float64), Array([-1.48868237e-02,  6.17862830e-02, -1.91785254e-10, -7.90581091e+01],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [1.2220477  1.85230899 3.95331689 4.31003859]
# (Array(-5669418.82739486, dtype=float64), Array([-2.12732245e-04,  5.30254560e-01, -9.07395787e-06, -5.08806169e-01],      dtype=float64))
# 6
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [0.9998334  2.00005114 4.07967523 4.00232239]
# (Array(5162677.05762338, dtype=float64), Array([-1.87388064e-03,  1.67367401e-02, -5.12452927e-11, -1.92958855e+01],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [1.10837041 1.98487949 4.09198907 4.03491152]
# (Array(-5668154.53092812, dtype=float64), Array([-9.60657841e-04, -1.50710211e+00,  4.32210428e-04, -1.92451519e+00],      dtype=float64))
# 7
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [0.99998989 1.99998105 3.88577012 4.00140297]
# (Array(5162971.21126699, dtype=float64), Array([ 1.34167583e-02,  7.43144560e-02, -8.04241118e-11, -9.04189131e+01],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [0.81717303 2.17242839 3.91560666 3.67738709]
# (Array(-5669140.88347346, dtype=float64), Array([-2.92684589e-03, -7.48267504e+00,  1.54544418e-03, -5.65515272e+00],      dtype=float64))
# 8
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [1.0001517  2.00004189 3.68304215 3.99837722]
# (Array(5163544.59611471, dtype=float64), Array([ 4.50085918e-03,  1.12789348e-01, -3.46232487e-10, -1.56352918e+02],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [0.94193734 1.98796494 3.68737571 4.02090544]
# (Array(-5667825.16740818, dtype=float64), Array([-3.53823053e-01, -1.09271856e+03,  2.02165822e-01, -5.43152325e+02],      dtype=float64))
# 9
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [0.99996886 1.99999899 4.1415171  3.99507588]
# (Array(5163754.53288398, dtype=float64), Array([ 1.35810338e-03,  8.51420026e-03, -1.90210625e-11, -9.17607816e+00],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [0.82139156 2.22378695 4.18082178 3.59186846]
# (Array(-5669223.67172146, dtype=float64), Array([-5.62085088e-05,  1.29174322e-01,  6.39942931e-07, -1.44382754e-01],      dtype=float64))
# 10
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [0.99965022 1.99991235 3.72879959 3.99803187]
# (Array(5163402.73899928, dtype=float64), Array([ 2.84210521e-03,  3.71131533e-02, -2.73907563e-11, -4.65164482e+01],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [0.91879253 2.09232003 3.74246732 3.81660701]
# (Array(-5669327.38090034, dtype=float64), Array([ 4.24879921e-03,  1.51367515e+01, -2.79209529e-03,  8.15329168e+00],      dtype=float64))
# 11
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [1.00009838 1.99984749 4.09007245 3.99638469]
# (Array(5163606.53214932, dtype=float64), Array([-2.71012052e-03,  1.59990767e-02, -1.25692790e-11, -1.82961280e+01],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [1.17621563 1.93640852 4.12923724 4.12857422]
# (Array(-5668867.93668171, dtype=float64), Array([-3.28082555e-04,  5.86281143e-01,  2.58489367e-05, -8.12409059e-01],      dtype=float64))
# 12
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [1.00006904 1.9999348  4.12489346 3.99955366]
# (Array(5163436.19367352, dtype=float64), Array([ 1.35373404e-03,  1.34565108e-01, -7.72260034e-11, -1.79655409e+02],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [0.98458868 1.97827465 4.13704295 4.02261877]
# (Array(-5668683.82326366, dtype=float64), Array([-6.37918943e-01, -2.04705938e+03,  3.55266378e-01, -1.00904162e+03],      dtype=float64))
# 13
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [0.99988397 1.99981704 3.98726131 4.002477  ]
# (Array(5162818.5630262, dtype=float64), Array([-2.81763832e-04,  6.03433974e-02, -4.81511497e-11, -7.81899019e+01],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [1.00275868 1.97898289 3.9850663  4.03336531]
# (Array(-5669496.44102668, dtype=float64), Array([-5.91972450e-04, -4.82339689e-01,  2.05578469e-04, -1.22599826e+00],      dtype=float64))
# 14
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [0.99988868 1.99996347 3.84226146 3.99935693]
# (Array(5163420.57636574, dtype=float64), Array([ 1.21096005e-03,  1.16171822e-01, -3.66557895e-11, -1.59962260e+02],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [0.98806348 1.99864514 3.83749016 3.98884739]
# (Array(-5669980.43344566, dtype=float64), Array([ 3.08082137e-04,  3.28743718e+00, -4.38969722e-04,  2.89395193e-01],      dtype=float64))
# 15
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [1.00008307 2.00006474 3.96420406 4.00023885]
# (Array(5163082.51234156, dtype=float64), Array([-4.21643353e-05,  5.23648091e-02,  2.81792367e-11, -6.71752217e+01],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [0.99868397 2.28353734 3.97602934 3.50032278]
# (Array(-5668938.31300755, dtype=float64), Array([-3.46935830e-04, -8.20173536e-02,  1.15980982e-04, -7.85975766e-01],      dtype=float64))
# 16
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [1.00026508 2.00001635 3.8505543  4.00319954]
# (Array(5162888.78714951, dtype=float64), Array([ 5.86188026e-03,  1.36616541e-01,  9.93196636e-11, -1.87284780e+02],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [0.95559636 2.08925945 3.84465835 3.82306787]
# (Array(-5669647.23285123, dtype=float64), Array([ 1.34241206e-01,  4.10655754e+02, -7.78935607e-02,  2.21652856e+02],      dtype=float64))
# 17
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [1.00010964 2.00007221 3.97355836 4.00238475]
# (Array(5162641.54891375, dtype=float64), Array([-7.93170226e-04,  7.40625858e-03, -4.85167462e-12, -8.32974822e+00],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [1.09997855 2.21319475 3.98390381 3.58911359]
# (Array(-5669948.59974454, dtype=float64), Array([-4.15484946e-01, -1.34039223e+03,  3.28581487e-01, -8.28489095e+02],      dtype=float64))
# 18
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [0.99998228 1.99998497 4.28663291 4.00254076]
# (Array(5163210.8722891, dtype=float64), Array([ 1.35614717e-02,  2.37894678e-01, -2.02980577e-10, -2.95776890e+02],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [0.94965748 1.84603226 4.29121098 4.32796713]
# (Array(-5669125.17523542, dtype=float64), Array([-1.69378466e-04,  4.93786094e-01, -2.10119103e-06, -5.13392651e-01],      dtype=float64))
# 19
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [1.00007558 1.99983837 4.16105884 4.00058201]
# (Array(5163008.33997123, dtype=float64), Array([ 7.99045913e-03,  3.14613084e-02, -4.87698770e-12, -3.31843311e+01],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [0.7281598  2.23538354 4.25051643 3.57949346]
# (Array(-5668525.37898077, dtype=float64), Array([-7.62230572e-05,  2.98084510e-01, -7.86307408e-06, -2.35990673e-01],      dtype=float64))
# 20
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [0.99994308 2.00012993 3.71776443 3.99528332]
# (Array(5163901.03419126, dtype=float64), Array([-1.41793560e-02,  8.26340620e-02, -1.35345735e-10, -1.11216687e+02],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [1.15299189 1.92505974 3.74922593 4.14506786]
# (Array(-5669614.42966436, dtype=float64), Array([-3.23431048e-04,  5.57382069e-01,  7.82219245e-06, -6.79952730e-01],      dtype=float64))
# 21
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [1.00003153 1.99990809 4.07665967 4.00006671]
# (Array(5163461.22157999, dtype=float64), Array([-2.79572042e-03,  1.66764323e-01, -1.20888366e-09, -2.27954263e+02],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [0.99898789 1.93102422 4.07953646 4.12686536]
# (Array(-5670129.36701094, dtype=float64), Array([-5.44816568e-03, -1.52001279e+01,  2.76705922e-03, -8.86712801e+00],      dtype=float64))
# 22
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [0.99998882 2.00007968 4.05198901 3.99354801]
# (Array(5163985.62968715, dtype=float64), Array([-1.86482064e-03,  1.56437001e-02, -1.79334325e-11, -1.80579218e+01],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [1.12580801 2.01527456 4.06617274 3.96172917]
# (Array(-5669399.60263887, dtype=float64), Array([-1.31583406e-04,  3.00722537e-01,  4.24569368e-07, -3.23432730e-01],      dtype=float64))
# 23
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [0.99994426 1.99985997 3.90036357 3.99979107]
# (Array(5163181.46573391, dtype=float64), Array([-3.89529389e-03,  4.88345878e-02, -1.95732874e-11, -6.25982326e+01],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [1.0777424  2.04596038 3.90420248 3.90761239]
# (Array(-5668577.02574215, dtype=float64), Array([-7.33628754e-02, -2.69417733e+02,  5.13702299e-02, -1.41149603e+02],      dtype=float64))
# 24
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [0.99992998 2.00001028 4.37499951 3.99994701]
# (Array(5163028.12239449, dtype=float64), Array([-1.18477704e-03,  1.14157696e-02, -4.31248925e-11, -1.26506421e+01],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [1.10171732 2.09995943 4.39292921 3.80348589]
# (Array(-5669248.53757512, dtype=float64), Array([-7.68613348e-05,  2.17638961e-01, -2.52202637e-07, -2.32426002e-01],      dtype=float64))
# 25
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [0.99985808 1.99998683 3.99331852 3.9997123 ]
# (Array(5163139.74585443, dtype=float64), Array([-7.32733134e-03,  3.94161971e-02, -8.18742851e-11, -4.85172059e+01],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [1.18014597 2.01094815 4.0248413  3.8958985 ]
# (Array(-5669493.11253866, dtype=float64), Array([-2.26586521e+00, -7.43028323e+03,  1.57174095e+00, -3.83384325e+03],      dtype=float64))
# 26
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [0.999987   1.99996336 4.12883714 3.99584105]
# (Array(5163684.58297381, dtype=float64), Array([ 8.77102343e-04,  2.36669618e-02,  1.44174672e-11, -2.81086899e+01],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [0.95847765 2.02691738 4.14173369 3.93574241]
# (Array(-5669729.96108332, dtype=float64), Array([-1.02901692e-04,  2.32626336e-01,  9.90447063e-07, -2.53735343e-01],      dtype=float64))
# 27
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [0.99989774 1.99983724 3.69871531 4.00331875]
# (Array(5164309.98323236, dtype=float64), Array([ 3.72776202e-02,  6.18492934e-01, -1.62326375e-09, -8.88316930e+02],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [0.93946645 1.93064107 3.70300203 4.13582272]
# (Array(-5669349.17924333, dtype=float64), Array([-1.23061062e-04,  2.70215269e-01, -6.20932304e-06, -2.54324282e-01],      dtype=float64))
# 28
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [1.00005302 2.00006183 4.07291598 3.99732103]
# (Array(5163445.48363004, dtype=float64), Array([-2.65047113e-03,  2.46941556e-02, -1.24477650e-10, -2.94897454e+01],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [1.10939663 2.01633722 4.08793115 3.95629322]
# (Array(-5669738.531478, dtype=float64), Array([-1.34818315e-04,  3.26232868e-01, -5.34085882e-07, -3.54191523e-01],      dtype=float64))
# 29
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [0.99985167 2.00015955 4.08827519 4.00077208]
# (Array(5162878.63032536, dtype=float64), Array([-2.04247767e-03,  1.29913218e-02, -1.47117596e-11, -1.47032388e+01],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [1.16337875 2.03252474 4.10189154 3.95449323]
# (Array(-5668524.49250083, dtype=float64), Array([ 5.47769128e-01,  1.77882086e+03, -3.96955878e-01,  9.11010767e+02],      dtype=float64))
# 30
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [1.00009965 2.00011324 4.41207985 3.99234324]
# (Array(5164165.02880383, dtype=float64), Array([ 4.42025104e-03,  2.00461281e-02, -3.71211950e-11, -2.06056008e+01],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [0.77171743 2.17831467 4.48274276 3.66388432]
# (Array(-5669554.13983371, dtype=float64), Array([-1.38027392e-04,  9.40071213e-01, -7.64686460e-05, -7.71641802e-01],      dtype=float64))
# 31
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [1.00011413 1.99991545 4.37417173 3.99555504]
# (Array(5163688.54975227, dtype=float64), Array([ 1.02575916e-04,  3.66729994e-03, -1.66461844e-11, -3.80233982e+00],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [0.97063043 2.26870202 4.37465555 3.5270115 ]
# (Array(-5668518.87676782, dtype=float64), Array([-7.36692322e-05,  1.41151315e-01,  6.93079171e-06, -2.06963965e-01],      dtype=float64))
# 32
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [0.9999964  2.0000689  3.92377574 3.99788808]
# (Array(5163331.02564472, dtype=float64), Array([ 1.25576951e-03,  1.34680109e-02, -1.58665303e-11, -1.55108111e+01],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [0.8958748  2.33164707 3.93800748 3.43411228]
# (Array(-5668447.4184463, dtype=float64), Array([ 5.14151049e-02,  1.83496791e+02, -3.90862698e-02,  1.22168497e+02],      dtype=float64))
# 33
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [1.00000611 1.99999554 3.31326698 4.00921479]
# (Array(5163159.11980629, dtype=float64), Array([ 3.15259995e-02,  4.85007908e-01, -1.47272194e-10, -7.69191999e+02],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [0.93381958 1.97526153 3.32062771 4.03756744]
# (Array(-5668621.65890571, dtype=float64), Array([-3.82353906e-01, -1.20525535e+03,  2.04627183e-01, -5.92342644e+02],      dtype=float64))
# 34
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [1.00003118 1.99989015 4.01706817 4.00602778]
# (Array(5162154.15330024, dtype=float64), Array([-4.28303786e-05,  1.66492098e-02, -9.89882065e-11, -1.93415115e+01],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [0.99796108 2.09140244 4.02075929 3.82534022]
# (Array(-5668579.04452282, dtype=float64), Array([-3.38847083e-04,  8.95606944e-02,  8.06928025e-05, -7.65345634e-01],      dtype=float64))
# 35
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [0.99993923 2.0003456  3.86414217 4.00790459]
# (Array(5162040.77169134, dtype=float64), Array([ 6.87450399e-03,  1.10992863e-01, -7.02322644e-11, -1.48444902e+02],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [0.94340051 2.068203   3.87020302 3.86497743]
# (Array(-5668914.49107805, dtype=float64), Array([-1.15499950e-04,  2.45106147e-01,  1.27918646e-06, -2.71417186e-01],      dtype=float64))
# 36
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [1.00008507 1.99995961 3.90281351 3.99896553]
# (Array(5163317.16804256, dtype=float64), Array([ 5.77958957e-03,  6.18032237e-02,  3.60409480e-11, -7.85059031e+01],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [0.90576301 2.11056707 3.90273553 3.77552936]
# (Array(-5670170.85757106, dtype=float64), Array([-6.14825975e-05,  1.17478268e+00, -1.16158079e-04, -2.44830931e-01],      dtype=float64))
# 37
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [1.00024625 2.00005069 3.8508337  3.99594188]
# (Array(5163645.20348068, dtype=float64), Array([-2.71320078e-04,  2.05717631e-02, -9.31144051e-12, -2.47179983e+01],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [1.01398083 2.16347204 3.83696018 3.69490708]
# (Array(-5668890.12001889, dtype=float64), Array([-2.74803839e-03, -9.34114276e+00,  1.92714355e-03, -5.60488185e+00],      dtype=float64))
# 38
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [1.00000451 2.00008672 3.88257465 4.00462163]
# (Array(5163126.470432, dtype=float64), Array([ 5.17704887e-02,  3.35760390e-01, -1.92231386e-09, -4.19380025e+02],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [0.85412814 1.98358071 3.92190581 4.02907434]
# (Array(-5668994.1799005, dtype=float64), Array([-1.18164996e-04,  2.63229460e-01, -4.63374913e-06, -2.78528461e-01],      dtype=float64))
# 39
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [1.00007463 2.00003213 3.93393376 4.00266447]
# (Array(5163011.30373122, dtype=float64), Array([ 1.02494256e-02,  1.56576440e-01, -1.01940234e-10, -2.10029819e+02],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [0.93896278 2.01241494 3.93923964 3.97079527]
# (Array(-5669051.78287025, dtype=float64), Array([ 6.58634327e-04,  4.95233822e+00, -7.82489427e-04,  6.12996483e-01],      dtype=float64))
# 40
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [1.0001743  2.00002157 4.00012443 3.9997805 ]
# (Array(5163202.77678994, dtype=float64), Array([ 1.84437845e-03,  6.82458118e-02, -9.23257026e-11, -8.86228487e+01],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [0.97692251 2.1398848  4.00982998 3.73802632]
# (Array(-5668648.13790607, dtype=float64), Array([-2.65559410e-04, -6.81212796e-01,  1.46776030e-04, -5.51869998e-01],      dtype=float64))
# 41
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [1.00000912 1.99995811 4.07750919 4.00963603]
# (Array(5162658.78926816, dtype=float64), Array([-5.72114217e-03,  3.97520216e-01, -4.63245442e-10, -5.47256362e+02],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [1.00761305 1.87125934 4.09038699 4.26707113]
# (Array(-5669374.02981939, dtype=float64), Array([ 5.22045324e-03,  1.97297909e+01, -2.92757055e-03,  6.68583187e+00],      dtype=float64))
# 42
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [0.99997348 1.99992602 4.20290766 3.99718515]
# (Array(5163451.11237181, dtype=float64), Array([-1.38791536e-03,  7.79186398e-03, -1.66228142e-11, -8.51207508e+00],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [1.18739395 2.07938578 4.22449637 3.84537402]
# (Array(-5668801.19106864, dtype=float64), Array([-6.37839892e-05,  1.41703436e-01,  2.74470208e-06, -1.73050898e-01],      dtype=float64))
# 43
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [1.00002548 2.00027512 4.17314718 4.00160255]
# (Array(5162909.26472188, dtype=float64), Array([-4.24259035e-03,  7.87011690e-02, -3.81182697e-10, -1.03803494e+02],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [1.05236103 1.99439889 4.15325145 4.07884172]
# (Array(-5669797.4226023, dtype=float64), Array([ 2.12704502e+00,  7.91059325e+03, -1.37755904e+00,  3.86511119e+03],      dtype=float64))
# 44
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [0.99993285 1.99994648 3.92796585 3.99765568]
# (Array(5163627.21320259, dtype=float64), Array([-1.55261832e-02,  9.74799523e-02,  1.32724942e-11, -1.33994056e+02],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [1.13522128 1.88119745 3.94792324 4.24480387]
# (Array(-5669300.64451421, dtype=float64), Array([-8.59774807e-03, -2.66645339e+01,  5.02002165e-03, -1.38428174e+01],      dtype=float64))
# 45
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [1.00004546 1.99985299 3.8366916  4.00223747]
# (Array(5163135.07849609, dtype=float64), Array([ 1.48173379e-03,  1.57648954e-01, -2.52577737e-10, -2.22012544e+02],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [0.99017396 1.98317823 3.8560613  4.04516494]
# (Array(-5667479.42863955, dtype=float64), Array([-1.09896782e-04,  2.07764563e-01,  8.89759729e-07, -2.34738904e-01],      dtype=float64))
# 46
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [0.9999684  2.00030513 3.97710496 3.99799471]
# (Array(5163417.5803827, dtype=float64), Array([ 7.61017791e-03,  7.21559493e-02, -4.39719150e-10, -9.04474958e+01],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [0.88351741 2.0208768  3.99352285 3.94552506]
# (Array(-5670166.13709483, dtype=float64), Array([ 7.04216812e-02,  2.41475088e+02, -4.39325143e-02,  1.21052955e+02],      dtype=float64))
# 47
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [1.00019462 2.00002647 4.01177512 3.99478555]
# (Array(5163778.63375792, dtype=float64), Array([ 2.86552168e-04,  2.07658057e-03, -2.71049849e-12, -2.16326367e+00],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [0.8306689  2.25051801 4.03462977 3.54702318]
# (Array(-5669465.58862732, dtype=float64), Array([-9.83396751e-05,  2.11723103e-01,  4.92640113e-07, -2.27891787e-01],      dtype=float64))
# 48
# Compute the observations -- Start
# Compute the observations -- End
# Optimisation Complete Observation Adam -- Start
# Optimisation Complete Observation Adam -- End
# [0.99989466 2.00005242 4.22831317 3.9981424 ]
# (Array(5163390.08107047, dtype=float64), Array([-4.67615056e-03,  4.91055539e-02, -1.01593178e-10, -6.24953172e+01],      dtype=float64))
# Optimisation Partial Observation Adam -- Start
# Optimisation Partial Observation Adam -- End
# [1.08365775 1.98700637 4.22586591 4.01452471]
# (Array(-5669751.5396637, dtype=float64), Array([-2.24735697e-03, -7.71095317e+00,  1.42399652e-03, -4.09511817e+00],      dtype=float64))
# 49

# %%
f = open(f'MLE_GLE_DW_complete={T}_dt_obs_{dt_obs}_dt_sim_{dt_simulation}.csv', 'w')
writer = csv.writer(f, delimiter='\t')
writer.writerow(D_sample_complete)
writer.writerow(λ_sample_complete)
writer.writerow(α_sample_complete)
writer.writerow(σ_sample_complete)
f.close()

f = open(f'MLE_GLE_DW_partial={T}_dt_obs_{dt_obs}_dt_sim_{dt_simulation}.csv', 'w')
writer = csv.writer(f, delimiter='\t')
writer.writerow(D_sample_partial)
writer.writerow(λ_sample_partial)
writer.writerow(α_sample_partial)
writer.writerow(σ_sample_partial)
f.close()
